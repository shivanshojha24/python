# %% [markdown]
# <a href="https://colab.research.google.com/github/shivanshojha24/python/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# one dimensional data

import pandas as pd

marks = pd.Series([85,90,78,95])

print(marks)
# Out:
# 0    85
# 1    90
# 2    78
# 3    95
# dtype: int64

# %%
import pandas as pd
df=pd.read_csv("/content/Zomato-data-.csv")
df.head(5)
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.columns
df.info()
df.describe()
df[["name","online_order"]]
df["name"]
df["name"]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB
# 0                      Jalsa
# 1             Spice Elephant
# 2            San Churro Cafe
# 3      Addhuri Udupi Bhojana
# 4              Grand Village
#                ...
# 143         Melting Melodies
# 144          New Indraprasta
# 145             Anna Kuteera
# 146                   Darbar
# ...
